# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
loan_df= pd.read_csv("Clean Leading Club data.csv")
loan_df
# Out:
#        Unnamed: 0  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0               0     5000.0       5000.0           4975.0   36 months
# 1               1     2500.0       2500.0           2500.0   60 months
# 2               2     2400.0       2400.0           2400.0   36 months
# 3               3    10000.0      10000.0          10000.0   36 months
# 4               5     5000.0       5000.0           5000.0   36 months
# ...           ...        ...          ...              ...         ...
# 39161       39781     2500.0       2500.0           1075.0   36 months
# 39162       39782     8500.0       8500.0            875.0   36 months
# 39163       39783     5000.0       5000.0           1325.0   36 months
# 39164       39784     5000.0       5000.0            650.0   36 months
# 39165       39785     7500.0       7500.0            800.0   36 months
#
#        installment grade sub_grade                   emp_title emp_length  \
# ...

# %%
loan_df.drop(columns='Unnamed: 0',inplace=True)

# %%
loan_df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  installment grade  \
# 0     5000.0       5000.0           4975.0   36 months       162.87     B
# 1     2500.0       2500.0           2500.0   60 months        59.83     C
# 2     2400.0       2400.0           2400.0   36 months        84.33     C
# 3    10000.0      10000.0          10000.0   36 months       339.31     C
# 4     5000.0       5000.0           5000.0   36 months       156.46     A
#
#   sub_grade             emp_title emp_length home_ownership  ...  \
# 0        B2                Others  10+ years           RENT  ...
# 1        C4                 Ryder   0-1 year           RENT  ...
# 2        C5                Others  10+ years           RENT  ...
# 3        C1   AIR RESOURCES BOARD  10+ years           RENT  ...
# 4        A4  Veolia Transportaton    3 years           RENT  ...
#
#    last_pymnt_amnt last_credit_pull_d last_fico_range_high  \
# 0           171.62           Sep-2016                744.0
# ...

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39166 entries, 0 to 39165
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                39166 non-null  float64
#  1   funded_amnt              39166 non-null  float64
#  2   funded_amnt_inv          39166 non-null  float64
#  3   term                     39166 non-null  object
#  4   installment              39166 non-null  float64
#  5   grade                    39166 non-null  object
#  6   sub_grade                39166 non-null  object
#  7   emp_title                39166 non-null  object
#  8   emp_length               39166 non-null  object
#  9   home_ownership           39166 non-null  object
#  10  annual_inc               39166 non-null  float64
#  11  verification_status      39166 non-null  object
#  12  issue_d                  39166 non-null  object
#  13  loan_status              39166 non-null  object
# ...

# %%
loan_df.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment  \
# count  39166.000000  39166.000000     39166.000000  39166.000000
# mean   11140.270260  10868.251162     10313.475666    323.410051
# std     7396.690652   7124.085788      7060.475019    208.406909
# min      500.000000    500.000000         0.000000     15.690000
# 25%     5400.000000   5300.000000      5000.000000    166.500000
# 50%    10000.000000   9600.000000      8875.000000    279.100000
# 75%    15000.000000  15000.000000     14224.776935    427.672500
# max    35000.000000  35000.000000     35000.000000   1305.190000
#
#          annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  3.916600e+04  39166.000000  39166.000000    39166.000000
# mean   6.892405e+04     13.296599      0.146326      715.025788
# std    6.404216e+04      6.675314      0.490856       35.866354
# min    4.000000e+03      0.000000      0.000000      625.000000
# ...

# %% [markdown]
# ### LOAN AMOUNT

# %%
fig, ax = plt.subplots(1, 3, figsize=(16,5))

sns.histplot(loan_df['loan_amnt'],kde=True, ax=ax[0], label='loan_amnt')
ax[0].set_title("Loan Applied by the Borrower", fontsize=14)
sns.histplot(loan_df['funded_amnt'],kde=True, ax=ax[1],  label='loan_amnt')
ax[1].set_title("Loan Funded", fontsize=14)
sns.histplot(loan_df['funded_amnt_inv'],kde=True, ax=ax[2],  label='loan_amnt')
ax[2].set_title("Loan Funded by the Investors", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Loan Funded by the Investors')

# %% [markdown]
# * Loan requested amount,Loan funded and amount invested by investors is nearly same.

# %%
fig=plt.figure(figsize=(14,8))
sns.barplot(y='loan_amnt',x='int_rate%',data=loan_df[:30])
# Out:
# <AxesSubplot:xlabel='int_rate%', ylabel='loan_amnt'>

# %% [markdown]
# * Higher the loan amount, higher will be the interest rate.

# %% [markdown]
# ### TERMS

# %%
terms=loan_df['term'].value_counts()
terms
# Out:
#  36 months    29041
#  60 months    10125
# Name: term, dtype: int64

# %%
fig=plt.figure(figsize=(10,6))
sns.barplot(x=terms.index,y=terms.values)
plt.show()

# %% [markdown]
# ### Interest Rate

# %%
loan_df['int_rate%']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4         7.90
#          ...
# 39161     8.07
# 39162    10.28
# 39163     8.07
# 39164     7.43
# 39165    13.75
# Name: int_rate%, Length: 39166, dtype: float64

# %%
fig,ax= plt.subplots(1, 2, figsize=(20,5))

sns.boxplot(x='term',y="int_rate%",ax=ax[0],data = loan_df)

sns.boxplot(x='emp_length',y="int_rate%",ax=ax[1],data = loan_df)
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='int_rate%'>

# %% [markdown]
# * The interest rate is more for a term of 60 months which is ~12.5-18% whereas for a term of 36 months, it is ~8-13%.
# * Thus, interest rate is affected by the term.
# * The interest rate is more for employment length of 11 years

# %%
fig,ax= plt.subplots(1, 2, figsize=(20,6))
sns.barplot(x="int_rate%",y='annual_inc',ax=ax[0],data = loan_df[:30])

sns.boxplot(x='home_ownership',y="int_rate%",ax=ax[1],data = loan_df)
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='int_rate%'>

# %% [markdown]
# ### Loan Status

# %%
sns.countplot(x=loan_df.loan_status)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
fig, axs = plt.subplots(1,2,figsize=(14,7))
sns.countplot(x='loan_status',data=loan_df,ax=axs[0])
axs[0].set_title("Frequency of each Loan Status")
loan_df.loan_status.value_counts().plot(x=None,y=None, kind='pie', ax=axs[1],autopct='%1.2f%%')
axs[1].set_title("Percentage of each Loan status")
plt.show()

# %% [markdown]
# * These plots indicate that a significant number of borrowers in our dataset paid off their loan. 85.75% of loan borrowers fully paid their borrowred amount, while 14.25% unfortunately defaulted.

# %% [markdown]
# ### Grade

# %%
fig, axes=plt.subplots(2,2, figsize=(15,10))
sns.barplot(ax=axes[0, 0],data=loan_df,x='grade',y='loan_amnt')

sns.barplot(ax=axes[0, 1],data=loan_df,x='grade',y='funded_amnt')

sns.barplot(ax=axes[1, 0],data=loan_df,x='grade',y='installment')

sns.barplot(ax=axes[1, 1],data=loan_df,x='grade',y='annual_inc')
# Out:
# <AxesSubplot:xlabel='grade', ylabel='annual_inc'>

# %%
plt.figure(figsize=(12,8))
plt.pie(loan_df['grade'].value_counts(),autopct='%.0f%%',labels=['B','A','C','D','E','F','G'],shadow=True)
plt.show()

# %% [markdown]
# ### Installment

# %%
loan_df['installment']
# Out:
# 0        162.87
# 1         59.83
# 2         84.33
# 3        339.31
# 4        156.46
#           ...
# 39161     78.42
# 39162    275.38
# 39163    156.84
# 39164    155.38
# 39165    255.43
# Name: installment, Length: 39166, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.histplot(x='installment', data=loan_df, bins=30, kde=True)
plt.title('Installment Distribution')
plt.xlabel('Installment')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
sns.barplot(x='home_ownership', y='installment',ax=ax[0] ,data=loan_df.groupby('home_ownership')['installment'].mean().sort_values(ascending=False).reset_index())
ax[0].set_title('Installment of Home Ownership')
ax[0].set_xlabel('House Ownership')
ax[0].set_ylabel('Total Installment')


sns.barplot(x='grade', y='installment',ax=ax[1], data=loan_df.groupby('grade')['installment'].mean().sort_values(ascending=False).reset_index())
ax[1].set_title('Installment of Each Group')
ax[1].set_xlabel('Grade')
ax[1].set_ylabel('Total Installment')
plt.show()

# %%
loan_df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'installment',
#        'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'fico_range_low', 'fico_range_high',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'last_fico_range_high', 'last_fico_range_low', 'policy_code',
#        'application_type', 'acc_now_delinq', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'int_rate%'],
#       dtype='object')

# %% [markdown]
# ### Empolyment Title

# %%
loan_df['emp_title'].value_counts()
# Out:
# Others                            2418
# US Army                            133
# Bank of America                    109
# IBM                                 66
# AT&T                                58
#                                   ...
# pershing lcc                         1
# Westgate Business Services LLC       1
# stop and shop co.                    1
# Dairyland                            1
# Evergreen Center                     1
# Name: emp_title, Length: 28417, dtype: int64

# %%
emp_loan = loan_df.groupby('emp_title')[['loan_amnt', 'funded_amnt','grade','annual_inc','emp_length', 'home_ownership']].max().sort_values(by='emp_title',ascending=True).reset_index()[:10]
emp_loan
# Out:
#                                            emp_title  loan_amnt  funded_amnt  \
# 0                                       old palm inc    14000.0      14000.0
# 1                             Brocade Communications    12000.0      12000.0
# 2                                        CenturyLink    10000.0       6525.0
# 3                    Department of Homeland Security     7800.0       7800.0
# 4                   Down To Earth Distributors, Inc.    18825.0      18825.0
# 5                                        Plaid, Inc.     2600.0       2600.0
# 6                    U.S. Dept. Of Homeland Security    20000.0      20000.0
# 7                  pacific crane maintenance company    35000.0      26675.0
# 8  $260M '06 vintage technology venture capital firm    10000.0      10000.0
# 9             (Collaborative) Abbott Nutrition Intl     18650.0      18650.0
#
#   grade  annual_inc emp_length home_ownership
# 0     D     50000.0    5 years       MORTGAGE
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='emp_title',x='loan_amnt', data=emp_loan)
plt.suptitle(" Employee Title Vs Loan ammount")
plt.xlabel('Loan Amount')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Verification Status

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='verification_status', data=loan_df)
plt.title("Verification Status")
plt.xlabel('')
plt.ylabel('No. of Income')
plt.show()

# %%
loan_df['verification_status'].value_counts()
# Out:
# Not Verified       16806
# Verified           12506
# Source Verified     9854
# Name: verification_status, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(loan_df['verification_status'].value_counts(),autopct='%.0f%%',labels=['Verified','Source Verified','Not Verified'])
plt.show()

# %%
loan_df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'installment',
#        'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'fico_range_low', 'fico_range_high',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'last_fico_range_high', 'last_fico_range_low', 'policy_code',
#        'application_type', 'acc_now_delinq', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'int_rate%'],
#       dtype='object')

# %% [markdown]
# ### Purpose

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='purpose', data=loan_df)
plt.title("Purpose for Loan Request")
plt.xlabel('No. of Purpose')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Fico Range

# %%
plt.figure(figsize=(16,8))

plt.suptitle('Fico Range Distribution')
plt.subplot(1,2,1)
sns.histplot(x='fico_range_high', data=loan_df, bins=10, kde=True)
plt.title('Fico Range High Distribution')
plt.xlabel('Ratio')
plt.ylabel('')

plt.subplot(1,2,2)
sns.histplot(x='fico_range_low', data=loan_df, bins=10, kde=True)
plt.title('Fico Range Low Distribution')
plt.xlabel('Ratio')
plt.ylabel('')
plt.show()

# %%
def relation_plot(x_col, y_col, x_label, y_label, title):
    plt.figure(figsize=(16,10))
    sns.set_context('talk')

    plt.subplot(2,2,1)
    plt.suptitle(title)
    sns.scatterplot(x=x_col, y=y_col, hue='grade', data=loan_df)
    plt.xlabel('')
    plt.ylabel(y_label)

    plt.subplot(2,2,2)
    sns.scatterplot(x=x_col, y=y_col, hue='home_ownership', data=loan_df)
    plt.xlabel('')
    plt.ylabel('')

    plt.subplot(2,2,3)
    sns.scatterplot(x=x_col, y=y_col, hue='loan_status', data=loan_df)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    plt.subplot(2,2,4)
    sns.scatterplot(x=x_col, y=y_col, hue='verification_status', data=loan_df)
    plt.xlabel(x_label)
    plt.ylabel('')

    plt.show()

# %% [markdown]
# ### Annual Income vs Loan Amount

# %%
relation_plot(x_col='annual_inc',y_col='loan_amnt',
              x_label='Annual Income',y_label='Loan Amount',
              title='Annual Income vs Loan Amount'
             )

# %% [markdown]
# ### Payment Vs Recovery

# %%
relation_plot(x_col='total_pymnt',y_col='recoveries',
              x_label='Payment',y_label='Recovery',
              title='Payment Vs Recovery'
             )

# %% [markdown]
# ### Loan Analysis by Issue Date

# %%
loan_df['issue_d']
# Out:
# 0        Dec-2011
# 1        Dec-2011
# 2        Dec-2011
# 3        Dec-2011
# 4        Dec-2011
#            ...
# 39161    Jul-2007
# 39162    Jul-2007
# 39163    Jul-2007
# 39164    Jul-2007
# 39165    Jun-2007
# Name: issue_d, Length: 39166, dtype: object

# %%
loan_df['issue_d']= pd.to_datetime(loan_df['issue_d'])
loan_df['issue_year']=pd.DatetimeIndex(loan_df['issue_d']).year
loan_df['issue_month']=pd.DatetimeIndex(loan_df['issue_d']).month

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39166 entries, 0 to 39165
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                39166 non-null  float64
#  1   funded_amnt              39166 non-null  float64
#  2   funded_amnt_inv          39166 non-null  float64
#  3   term                     39166 non-null  object
#  4   installment              39166 non-null  float64
#  5   grade                    39166 non-null  object
#  6   sub_grade                39166 non-null  object
#  7   emp_title                39166 non-null  object
#  8   emp_length               39166 non-null  object
#  9   home_ownership           39166 non-null  object
#  10  annual_inc               39166 non-null  float64
#  11  verification_status      39166 non-null  object
#  12  issue_d                  39166 non-null  datetime64[ns]
# ...

# %%
loan_df['issue_year'].unique()
# Out:
# array([2011, 2010, 2009, 2008, 2007], dtype=int64)

# %%
plt.figure(figsize=(12,8))
sns.countplot(loan_df['issue_year'])
plt.show()
# Out:
# C:\Users\Yash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='issue_month', y='loan_amnt', data=(loan_df[loan_df['issue_year']==2007]))
# Out:
# <AxesSubplot:xlabel='issue_month', ylabel='loan_amnt'>

# %% [markdown]
# ### Average Loans In Each Months Of Year

# %%
plt.figure(figsize=(16,16))
sns.set_style('whitegrid')

plt.subplot(3,2,1)
plt.suptitle('Loans In Each Months')
sns.barplot(x='issue_month', y='loan_amnt', data=loan_df[loan_df['issue_year']==2007])
plt.title('Year 2007')
plt.xlabel('')
plt.ylabel('Amount')

plt.subplot(3,2,2)
sns.barplot(x='issue_month', y='loan_amnt', data=loan_df[loan_df['issue_year']==2008])
plt.title('Year 2008')
plt.xlabel('')
plt.ylabel('')

plt.subplot(3,2,3)
sns.barplot(x='issue_month', y='loan_amnt', data=loan_df[loan_df['issue_year']==2009])
plt.title('Year 2009')
plt.xlabel('')
plt.ylabel('Amount')

plt.subplot(3,2,4)
sns.barplot(x='issue_month', y='loan_amnt', data=loan_df[loan_df['issue_year']==2010])
plt.title('Year 2010')
plt.xlabel('Months')
plt.ylabel('')

plt.subplot(3,2,5)
sns.barplot(x='issue_month', y='loan_amnt', data=loan_df[loan_df['issue_year']==2011])
plt.title('Year 2012')
plt.xlabel('Months')
plt.ylabel('Amount')

plt.show()

# %% [markdown]
# ### Loans Distrubution

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,5))
sns.histplot(loan_df['issue_year'],kde=True, ax=ax[0], label='loan year')
ax[0].set_title("Loans by year", fontsize=14)

sns.histplot(loan_df['issue_month'],kde=True, ax=ax[1], label='loan year')
ax[1].set_title("Loans by months", fontsize=14)

plt.show()

# %% [markdown]
# * Number of loans has been consistently increasing over the last 5 years.
# * There does not seem to be a strong seasonality of loans during any of the 12 months.
# * Though loans are lowest in Feb and maximum in December

# %% [markdown]
# ### Analysis by Geography

# %%
loan_df['addr_state'].unique()
# Out:
# array(['AZ', 'GA', 'IL', 'CA', 'NC', 'TX', 'VA', 'MO', 'CT', 'UT', 'FL',
#        'PA', 'MN', 'NY', 'NJ', 'OR', 'KY', 'OH', 'SC', 'RI', 'LA', 'MA',
#        'WA', 'WI', 'AL', 'KS', 'NV', 'AK', 'CO', 'MD', 'WV', 'VT', 'MI',
#        'DC', 'SD', 'NH', 'AR', 'NM', 'MT', 'HI', 'WY', 'OK', 'DE', 'MS',
#        'TN', 'IA', 'NE', 'ID', 'IN', 'ME'], dtype=object)

# %% [markdown]
# ### Making list of state according to there region

# %%
west = ['CA', 'OR', 'UT','WA', 'CO', 'NV', 'AK', 'MT', 'HI', 'WY', 'ID']
south_west = ['AZ', 'TX', 'NM', 'OK']
south_east = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE', 'MS', 'TN' ]
mid_west = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
north_east = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']

# %%
def finding_regions(state):
    if state in west:
        return 'West'
    elif state in south_west:
        return 'SouthWest'
    elif state in south_east:
        return 'SouthEast'
    elif state in mid_west:
        return 'MidWest'
    elif state in north_east:
        return 'NorthEast'

loan_df['region'] = loan_df['addr_state'].apply(finding_regions)

# %%
loan_df['region'].value_counts()
# Out:
# NorthEast    10593
# West         10224
# SouthEast     8803
# MidWest       5508
# SouthWest     4038
# Name: region, dtype: int64

# %%
plt.figure(figsize=(12,8))
loan_df["region"].value_counts().plot.pie(autopct='%.0f%%', shadow=True)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,10))

sns.barplot(x="loan_status", y="loan_amnt", hue="region", ax=ax[0], palette = 'rocket', data=loan_df, estimator=lambda x: len(x) / len(loan_df) * 100)
ax[0].set(ylabel="(%)")

sns.barplot(x="loan_status", y="loan_amnt", hue="region", ax=ax[1], palette = 'rocket', data=loan_df, estimator=lambda x: len(x) / len(loan_df) * 100)
ax[1].set(ylabel="(%)")

plt.show()
